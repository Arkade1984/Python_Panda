# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('C:\\data\\dallas.csv')

# %%
df
# Out:
#               Neighborhood                Suburb        Location  Tornadoes  \
# 0                      NaN            Richardson             NaN        4.0
# 1                      NaN                   NaN           North        NaN
# 2                   Canyon                   NaN             NaN        NaN
# 3   Cottonwood Creek South            Richardson           North        4.0
# 4             Heights Park            Richardson           North        1.0
# 5       Canyon Creek South            Richardson           North        1.0
# 6                   Copell      Suburb of Dallas      North West        6.0
# 7              Timberbrook                 Plano      North East        1.0
# 8          University Park      Suburb of Dallas         Central        4.0
# 9         Preston Highands      Suburb of Dallas       Far North       10.0
# 10      Canyon Creek North            Richardson           North        2.0
# ...

# %%
df.replace('Missing', np.nan, inplace=True)
df.dropna()
# Out:
#               Neighborhood                Suburb        Location  Tornadoes  \
# 3   Cottonwood Creek South            Richardson           North        4.0
# 4             Heights Park            Richardson           North        1.0
# 5       Canyon Creek South            Richardson           North        1.0
# 6                   Copell      Suburb of Dallas      North West        6.0
# 7              Timberbrook                 Plano      North East        1.0
# 8          University Park      Suburb of Dallas         Central        4.0
# 9         Preston Highands      Suburb of Dallas       Far North       10.0
# 10      Canyon Creek North            Richardson           North        2.0
# 11         Greenwood Hills            Richardson      North East        1.0
# 12                  Irving                Dallas      North West        7.0
# 13                  Denton                Dallas  Far North West        5.0
# ...

# %%
df.dropna().set_index('Suburb')
# Out:
#                                 Neighborhood        Location  Tornadoes  \
# Suburb
# Richardson            Cottonwood Creek South           North        4.0
# Richardson                      Heights Park           North        1.0
# Richardson                Canyon Creek South           North        1.0
# Suburb of Dallas                      Copell      North West        6.0
# Plano                            Timberbrook      North East        1.0
# Suburb of Dallas             University Park         Central        4.0
# Suburb of Dallas            Preston Highands       Far North       10.0
# Richardson                Canyon Creek North           North        2.0
# Richardson                   Greenwood Hills      North East        1.0
# Dallas                                Irving      North West        7.0
# Dallas                                Denton  Far North West        5.0
# Suburb of Dallas                      Murphy  Far North East        3.0
# ...

# %%
df.head(5).dropna()
# Out:
#              Neighborhood      Suburb Location  Tornadoes Safe Rating
# 3  Cottonwood Creek South  Richardson    North        4.0           B
# 4            Heights Park  Richardson    North        1.0           B

# %%
df.tail(5).dropna()
# Out:
#         Neighborhood            Suburb       Location  Tornadoes Safe Rating
# 26      Flower Mound  Suburb of Dallas     North West        5.0           B
# 27  Highland Village  Suburb of Dallas     North West        1.0           B
# 28        Colleyvile       Forth Worth     North West        3.0           B
# 29   Greenland Hills            Dallas  Central North        0.0           B
# 30          McKinney            Dallas      Far North        8.0           B

# %%
df.iloc[:3,:5]
# Out:
#   Neighborhood      Suburb Location  Tornadoes Safe Rating
# 0          NaN  Richardson      NaN        4.0           F
# 1          NaN         NaN    North        NaN           B
# 2       Canyon         NaN      NaN        NaN         NaN

# %%
df.sort_values('Tornadoes').dropna()
# Out:
#               Neighborhood                Suburb        Location  Tornadoes  \
# 18              Double Oak      Suburb of Dallas  Far North West        0.0
# 17                 Lantana      Suburb of Dallas  Far North West        0.0
# 29         Greenland Hills                Dallas   Central North        0.0
# 25             Prestonwood                Dallas           North        1.0
# 4             Heights Park            Richardson           North        1.0
# 5       Canyon Creek South            Richardson           North        1.0
# 7              Timberbrook                 Plano      North East        1.0
# 11         Greenwood Hills            Richardson      North East        1.0
# 23              Deep Ellum                Dallas   Central North        1.0
# 27        Highland Village      Suburb of Dallas      North West        1.0
# 24                 Arapaho            Richardson           North        2.0
# ...

# %%
df.groupby(['Suburb'])['Tornadoes'].sum()
# Out:
# Suburb
# Dallas                  34.0
# Forth Worth              8.0
# Plano                    8.0
# Richardson              15.0
# Suburb of Dallas        48.0
# Suburb of Fort Worth     9.0
# Name: Tornadoes, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Neighborhood  29 non-null     object
#  1   Suburb        29 non-null     object
#  2   Location      29 non-null     object
#  3   Tornadoes     29 non-null     float64
#  4   Safe Rating   30 non-null     object
# dtypes: float64(1), object(4)
# memory usage: 1.3+ KB

# %%
df.describe()
# Out:
#        Tornadoes
# count  29.000000
# mean    4.206897
# std     3.519124
# min     0.000000
# 25%     1.000000
# 50%     4.000000
# 75%     7.000000
# max    12.000000

# %%
df.dropna().plot(x="Neighborhood", y=["Tornadoes"], kind="bar")
# Out:
# <AxesSubplot:xlabel='Neighborhood'>

# %%
notin = ['Far North West']
df[(df['Safe Rating'] == 'A') & (df['Tornadoes'] < 7) & (~df['Location'].isin(notin))]
# Out:
#           Neighborhood            Suburb    Location  Tornadoes Safe Rating
# 5   Canyon Creek South        Richardson       North        1.0           A
# 6               Copell  Suburb of Dallas  North West        6.0           A
# 7          Timberbrook             Plano  North East        1.0           A
# 10  Canyon Creek North        Richardson       North        2.0           A
# 11     Greenwood Hills        Richardson  North East        1.0           A
